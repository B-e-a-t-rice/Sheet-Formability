# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
from sklearn.model_selection import train_test_split

from import_class import DataHandler
from CNN_class import CNN_3
# Out:
# 2025-01-16 10:58:24.572424: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-16 10:58:24.580380: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 10:58:24.589526: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 10:58:24.592265: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
data_handler = DataHandler()
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737050306.535996 3895529 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737050306.559653 3895529 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
train_dataset, val_dataset, X_test, y_test = data_handler.load_data("all_inputs_with_sobel512.npy", "all_targets_with_sobel512.npy")
# Out:
# input shape: (3467, 512, 512, 2)
# X test shape: (694, 512, 512, 2)

# %%
cnn = CNN_3((512,512,2))
# Out:
# /home/user/anaconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.compile_model(learning_rate=0.00001)

# %%
training = cnn.train_model(train_data=train_dataset, validation_data=val_dataset)
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737050325.730061 3895668 service.cc:146] XLA service 0x76f33c0053d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1737050325.730082 3895668 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2025-01-16 10:58:45.755065: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-01-16 10:58:45.881783: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#  5/70 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5193 - loss: 0.8942
# I0000 00:00:1737050328.293716 3895668 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# ...

# %%
"max val accuracy: {0}, min val loss: {1}".format(max(training.history['val_accuracy']),min(training.history['val_loss']))
# Out:
# 'max val accuracy: 0.7585585713386536, min val loss: 0.524840235710144'

# %%
"max val accuracy: {0}, min val loss: {1}".format(max(training.history['val_accuracy']),min(training.history['val_loss']))
# Out:
# 'max val accuracy: 0.7549549341201782, min val loss: 0.5094172954559326'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(training.history['accuracy'])
plt.plot(training.history['val_accuracy'])
plt.legend(['train', 'validation'], loc='lower right')
plt.title('Accuracy')
plt.ylabel("Accuracy")
plt.xlabel("epochs")
plt.show()

# %%
plt.plot(training.history['loss'])
plt.plot(training.history['val_loss'])
plt.legend(['train', 'validation'], loc='upper left')
plt.title('Loss')
plt.ylabel("Loss")
plt.xlabel("epochs")
plt.ylim(0,1)
plt.show()

# %%
test_metrics = cnn.evaluate_model(X_test=X_test,y_test=y_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7424 - loss: 0.5666

# %%
test_metrics
# Out:
# [0.5759810209274292, 0.7247838377952576]

# %%
cnn.predict(X=X_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# array([[0.99576783],
#        [0.9721111 ],
#        [0.26000178],
#        [0.8150874 ],
#        [0.26101762],
#        [0.81724477],
#        [0.09176087],
#        [0.86552405],
#        [0.8939977 ],
#        [0.714786  ],
#        [0.527739  ],
#        [0.9049107 ],
#        [0.4947426 ],
#        [0.13982052],
#        [0.54892814],
#        [0.67778224],
#        [0.8569491 ],
#        [0.9912723 ],
#        [0.8588607 ],
#        [0.93915516],
#        [0.37634808],
#        [0.9923496 ],
#        [0.9840618 ],
#        [0.61680496],
#        [0.98122483],
#        [0.93002933],
#        [0.02067594],
#        [0.8520818 ],
#        [0.15398157],
#        [0.997917  ],
#        [0.58118224],
#        [0.61637187],
#        [0.09291969],
#        [0.6422614 ],
#        [0.99886215],
#        [0.03218008],
#        [0.4806936 ],
#        [0.99845994],
#        [0.13836183],
#        [0.01377416],
#        [0.02540768],
# ...
