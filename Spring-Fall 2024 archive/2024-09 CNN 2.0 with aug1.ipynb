# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from PIL import Image 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import sklearn as sk
from sklearn.model_selection import train_test_split
import pickle

print(tf.__version__)
# Out:
# 2024-09-24 10:30:02.723586: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-24 10:30:02.807873: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-24 10:30:02.841959: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-24 10:30:02.852217: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-24 10:30:02.911826: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-24 10:30:03.463942: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.17.0

# %%
gpus = tf.config.list_physical_devices('GPU')
gpuid = 0 #int(args.gpu_id)                                                                                                                           
if gpus:
  # Restrict TensorFlow to only allocate X GB of memory on the first GPU                                                                              
  try:
    tf.config.set_visible_devices(gpus[gpuid], 'GPU')
    tf.config.experimental.set_memory_growth(gpus[gpuid], True)
    '''
    tf.config.set_logical_device_configuration(
        gpus[gpuid],
        [tf.config.LogicalDeviceConfiguration(memory_limit=12000)])
    '''
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized                                                                                   
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727195415.917085    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727195416.026956    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727195416.030329    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727195416.033419    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727195416.036904    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727195416.038572    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727195416.125668    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727195416.126852    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727195416.127965    5899 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-24 10:30:16.129343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13824 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
#with tf.device('/job:localhost/replica:0/task:0/device:GPU:0'):
inputs = np.load("all_inputs_aug.npy")

# %%
targets = np.load("all_targets_aug.npy")
# train test split
X_train, X_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.2)

# %%
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
# added more layers because original model didn't have enough downsampling
# old model had 266M params
conv_dim = 8
ff_dim = 32
k_dim = 5
pool_dim = 2
drop_rate = 0.1

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(conv_dim, kernel_size = (k_dim, k_dim), activation='relu', input_shape=(1024, 1024, 1)),
  tf.keras.layers.Conv2D(conv_dim, kernel_size = (k_dim, k_dim), activation='relu'),
  tf.keras.layers.MaxPooling2D((pool_dim, pool_dim)),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(ff_dim, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')  
])

model.summary()
# Out:
# /home/user/anaconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 1020, 1020, 8)  │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 1016, 1016, 8)  │         1,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 508, 508, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 508, 508, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2064512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │    66,064,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66,066,265 (252.02 MB)
#  Trainable params: 66,066,265 (252.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
conv_dim = 16
ff_dim = 32
k_dim = 21
pool_dim = 3
drop_rate = 0.2

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(conv_dim, kernel_size = (k_dim, k_dim), activation='relu', input_shape=(512, 512, 1)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.ReLU(),
  tf.keras.layers.AveragePooling2D(pool_dim,pool_dim),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Conv2D(conv_dim, kernel_size = (k_dim, k_dim), padding ='valid'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.ReLU(),
  tf.keras.layers.AveragePooling2D(pool_dim,pool_dim),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Conv2D(conv_dim, kernel_size = (k_dim, k_dim), padding ='valid'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.ReLU(),
  tf.keras.layers.AveragePooling2D(pool_dim,pool_dim),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(ff_dim, activation='relu'),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Dense(1, activation='sigmoid')  
])

model.summary()
# Out:
# /home/user/anaconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 492, 492, 16)   │         7,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 492, 492, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 492, 492, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 164, 164, 16)   │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 164, 164, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 144, 144, 16)   │       112,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 144, 144, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 144, 144, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 48, 48, 16)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 48, 48, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 16)     │       112,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 28, 28, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 28, 28, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 9, 9, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 9, 9, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1296)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        41,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 274,625 (1.05 MB)
#  Trainable params: 274,529 (1.05 MB)
#  Non-trainable params: 96 (384.00 B)

# %%
#model.compile(optimizer=Adam(learning_rate=1e-4),
#model.compile(optimizer=Adam(learning_rate=1e-2),
#model.compile(optimizer=Adam(learning_rate=1e-5),
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='binary_crossentropy',  
              metrics=['accuracy'])

# %%
batchsize = 8
# buffer size is # of elements, not MB
train_dataset = tf.data.Dataset.from_tensor_slices((X_train,y_train))
train_dataset = train_dataset.shuffle(buffer_size=batchsize*2).batch(batchsize)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test,y_test))
test_dataset = test_dataset.shuffle(buffer_size=batchsize*2).batch(batchsize)

# %%
model_checkpoint = ModelCheckpoint(
  filepath='checkpoint2.model.keras',
  monitor='val_loss',
  mode='min',
  save_best_only=True)

optim = model.fit(X_train,y_train, 
                  epochs=100, 
                  validation_split =.2,
                  callbacks=[model_checkpoint])
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726024990.363529    3506 service.cc:146] XLA service 0x7b8ad0012500 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1726024990.363558    3506 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2024-09-10 21:23:10.392015: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-10 21:23:10.554859: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-09-10 21:23:16.173658: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng2{k2=1,k3=0} for conv (f32[32,16,164,164]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,144,144]{3,2,1,0}, f32[16,16,21,21]{3,2,1,0}), window={size=21x21}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-10 21:23:16.503051: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.329826644s
# Trying algorithm eng2{k2=1,k3=0} for conv (f32[32,16,164,164]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,144,144]{3,2,1,0}, f32[16,16,21,21]{3,2,1,0}), window={size=21x21}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#   4/137 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.6048 - loss: 0.6633
# I0000 00:00:1726025002.465255    3506 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7209 - loss: 0.5737
# E0000 00:00:1726025013.433906    3506 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1726025013.516930    3506 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1726025014.749155    3506 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1726025014.828994    3506 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - accuracy: 0.7211 - loss: 0.5733 - val_accuracy: 0.5380 - val_loss: 2.5289
# Epoch 2/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.7955 - loss: 0.4266 - val_accuracy: 0.5490 - val_loss: 0.6962
# Epoch 3/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8373 - loss: 0.3484 - val_accuracy: 0.6132 - val_loss: 1.2388
# Epoch 4/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8688 - loss: 0.2916 - val_accuracy: 0.4693 - val_loss: 9.4900
# Epoch 5/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8949 - loss: 0.2440 - val_accuracy: 0.5820 - val_loss: 1.5093
# Epoch 6/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9199 - loss: 0.1991 - val_accuracy: 0.5142 - val_loss: 2.6840
# Epoch 7/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9367 - loss: 0.1638 - val_accuracy: 0.4794 - val_loss: 5.7791
# Epoch 8/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9424 - loss: 0.1522 - val_accuracy: 0.4693 - val_loss: 6.1718
# Epoch 9/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9486 - loss: 0.1219 - val_accuracy: 0.7654 - val_loss: 1.0958
# Epoch 10/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9623 - loss: 0.1016 - val_accuracy: 0.5133 - val_loss: 3.5464
# Epoch 11/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9680 - loss: 0.0906 - val_accuracy: 0.6178 - val_loss: 2.6920
# Epoch 12/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9740 - loss: 0.0764 - val_accuracy: 0.5069 - val_loss: 3.7922
# Epoch 13/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9741 - loss: 0.0646 - val_accuracy: 0.5591 - val_loss: 2.3965
# Epoch 14/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9800 - loss: 0.0583 - val_accuracy: 0.8258 - val_loss: 0.6694
# Epoch 15/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9794 - loss: 0.0570 - val_accuracy: 0.7461 - val_loss: 1.2571
# Epoch 16/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9771 - loss: 0.0657 - val_accuracy: 0.4757 - val_loss: 6.9351
# Epoch 17/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9843 - loss: 0.0418 - val_accuracy: 0.7764 - val_loss: 0.9022
# Epoch 18/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9863 - loss: 0.0379 - val_accuracy: 0.7864 - val_loss: 1.3264
# Epoch 19/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9896 - loss: 0.0342 - val_accuracy: 0.5225 - val_loss: 3.4266
# Epoch 20/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9910 - loss: 0.0242 - val_accuracy: 0.8203 - val_loss: 0.4927
# Epoch 21/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9949 - loss: 0.0206 - val_accuracy: 0.9578 - val_loss: 0.1223
# Epoch 22/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9819 - loss: 0.0455 - val_accuracy: 0.7104 - val_loss: 1.8774
# Epoch 23/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9873 - loss: 0.0384 - val_accuracy: 0.8029 - val_loss: 0.6215
# Epoch 24/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9906 - loss: 0.0263 - val_accuracy: 0.8973 - val_loss: 0.5100
# Epoch 25/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9865 - loss: 0.0331 - val_accuracy: 0.9523 - val_loss: 0.1224
# Epoch 26/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9895 - loss: 0.0283 - val_accuracy: 0.7470 - val_loss: 0.8868
# Epoch 27/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9931 - loss: 0.0152 - val_accuracy: 0.4803 - val_loss: 6.3124
# Epoch 28/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9922 - loss: 0.0239 - val_accuracy: 0.5985 - val_loss: 4.5139
# Epoch 29/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9864 - loss: 0.0366 - val_accuracy: 0.7021 - val_loss: 1.5677
# Epoch 30/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9933 - loss: 0.0209 - val_accuracy: 0.8634 - val_loss: 0.5254
# Epoch 31/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9976 - loss: 0.0107 - val_accuracy: 0.8414 - val_loss: 0.5950
# Epoch 32/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9914 - loss: 0.0235 - val_accuracy: 0.7186 - val_loss: 2.1143
# Epoch 33/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9926 - loss: 0.0203 - val_accuracy: 0.6691 - val_loss: 1.5611
# Epoch 34/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9928 - loss: 0.0213 - val_accuracy: 0.8928 - val_loss: 0.3640
# Epoch 35/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9916 - loss: 0.0218 - val_accuracy: 0.4693 - val_loss: 10.1083
# Epoch 36/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9751 - loss: 0.0682 - val_accuracy: 0.6324 - val_loss: 3.2608
# Epoch 37/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9904 - loss: 0.0309 - val_accuracy: 0.6214 - val_loss: 3.0424
# Epoch 38/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9954 - loss: 0.0120 - val_accuracy: 0.7397 - val_loss: 1.8352
# Epoch 39/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9930 - loss: 0.0250 - val_accuracy: 0.7654 - val_loss: 1.3303
# Epoch 40/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9905 - loss: 0.0254 - val_accuracy: 0.9432 - val_loss: 0.2729
# Epoch 41/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9943 - loss: 0.0199 - val_accuracy: 0.7360 - val_loss: 1.9258
# Epoch 42/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9901 - loss: 0.0270 - val_accuracy: 0.7507 - val_loss: 2.1527
# Epoch 43/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9947 - loss: 0.0132 - val_accuracy: 0.5903 - val_loss: 4.7342
# Epoch 44/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9955 - loss: 0.0129 - val_accuracy: 0.5885 - val_loss: 4.8771
# Epoch 45/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9934 - loss: 0.0148 - val_accuracy: 0.6462 - val_loss: 2.5587
# Epoch 46/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9956 - loss: 0.0129 - val_accuracy: 0.5380 - val_loss: 7.3396
# Epoch 47/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9957 - loss: 0.0103 - val_accuracy: 0.5234 - val_loss: 7.1700
# Epoch 48/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9929 - loss: 0.0219 - val_accuracy: 0.9377 - val_loss: 0.1722
# Epoch 49/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9971 - loss: 0.0083 - val_accuracy: 0.7296 - val_loss: 2.3712
# Epoch 50/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9947 - loss: 0.0123 - val_accuracy: 0.6315 - val_loss: 2.5316
# Epoch 51/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9969 - loss: 0.0068 - val_accuracy: 0.8955 - val_loss: 0.3520
# Epoch 52/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9929 - loss: 0.0176 - val_accuracy: 0.5518 - val_loss: 5.7841
# Epoch 53/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9949 - loss: 0.0151 - val_accuracy: 0.9129 - val_loss: 0.3143
# Epoch 54/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9969 - loss: 0.0088 - val_accuracy: 0.7617 - val_loss: 1.8491
# Epoch 55/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9971 - loss: 0.0096 - val_accuracy: 0.5646 - val_loss: 6.4645
# Epoch 56/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9987 - loss: 0.0077 - val_accuracy: 0.7296 - val_loss: 2.0277
# Epoch 57/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9959 - loss: 0.0136 - val_accuracy: 0.9927 - val_loss: 0.0348
# Epoch 58/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9988 - loss: 0.0071 - val_accuracy: 0.9533 - val_loss: 0.2259
# Epoch 59/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9936 - loss: 0.0248 - val_accuracy: 0.8717 - val_loss: 0.4181
# Epoch 60/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9922 - loss: 0.0173 - val_accuracy: 0.7800 - val_loss: 1.1293
# Epoch 61/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9957 - loss: 0.0103 - val_accuracy: 0.7745 - val_loss: 1.3961
# Epoch 62/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9955 - loss: 0.0128 - val_accuracy: 0.9038 - val_loss: 0.4783
# Epoch 63/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9946 - loss: 0.0205 - val_accuracy: 0.7901 - val_loss: 0.8976
# Epoch 64/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9911 - loss: 0.0251 - val_accuracy: 0.9047 - val_loss: 0.3062
# Epoch 65/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9972 - loss: 0.0086 - val_accuracy: 0.9835 - val_loss: 0.0557
# Epoch 66/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9986 - loss: 0.0065 - val_accuracy: 0.9560 - val_loss: 0.1916
# Epoch 67/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9970 - loss: 0.0089 - val_accuracy: 0.9872 - val_loss: 0.0398
# Epoch 68/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 0.6563 - val_loss: 2.7609
# Epoch 69/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9989 - loss: 0.0041 - val_accuracy: 0.7883 - val_loss: 1.4134
# Epoch 70/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9965 - loss: 0.0098 - val_accuracy: 0.9239 - val_loss: 0.4820
# Epoch 71/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9979 - loss: 0.0078 - val_accuracy: 0.9835 - val_loss: 0.0852
# Epoch 72/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.6453 - val_loss: 3.9637
# Epoch 73/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9940 - loss: 0.0162 - val_accuracy: 0.9707 - val_loss: 0.1150
# Epoch 74/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9953 - loss: 0.0138 - val_accuracy: 0.9523 - val_loss: 0.1830
# Epoch 75/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9975 - loss: 0.0110 - val_accuracy: 0.6471 - val_loss: 2.5267
# Epoch 76/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9984 - loss: 0.0064 - val_accuracy: 0.9368 - val_loss: 0.2646
# Epoch 77/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9918 - val_loss: 0.0432
# Epoch 78/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.4876 - val_loss: 6.0999
# Epoch 79/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9970 - loss: 0.0095 - val_accuracy: 0.8928 - val_loss: 0.5126
# Epoch 80/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9986 - loss: 0.0037 - val_accuracy: 0.9010 - val_loss: 0.3459
# Epoch 81/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9968 - loss: 0.0106 - val_accuracy: 0.9927 - val_loss: 0.0353
# Epoch 82/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9985 - loss: 0.0038 - val_accuracy: 0.7168 - val_loss: 2.5498
# Epoch 83/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9953 - loss: 0.0163 - val_accuracy: 0.8002 - val_loss: 0.8666
# Epoch 84/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9988 - loss: 0.0051 - val_accuracy: 0.9010 - val_loss: 0.3952
# Epoch 85/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9970 - loss: 0.0068 - val_accuracy: 0.6004 - val_loss: 4.7055
# Epoch 86/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9964 - loss: 0.0150 - val_accuracy: 0.9945 - val_loss: 0.0272
# Epoch 87/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9970 - loss: 0.0091 - val_accuracy: 0.5820 - val_loss: 11.4675
# Epoch 88/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9946 - loss: 0.0185 - val_accuracy: 0.8698 - val_loss: 0.5054
# Epoch 89/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.8570 - val_loss: 0.7026
# Epoch 90/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9972 - loss: 0.0088 - val_accuracy: 0.7819 - val_loss: 0.9249
# Epoch 91/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9987 - loss: 0.0067 - val_accuracy: 0.7379 - val_loss: 1.2738
# Epoch 92/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9961 - loss: 0.0140 - val_accuracy: 0.9386 - val_loss: 0.2461
# Epoch 93/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9984 - loss: 0.0054 - val_accuracy: 0.7333 - val_loss: 2.6173
# Epoch 94/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9984 - loss: 0.0048 - val_accuracy: 0.4830 - val_loss: 23.9279
# Epoch 95/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9913 - loss: 0.0380 - val_accuracy: 0.8964 - val_loss: 0.3797
# Epoch 96/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9968 - loss: 0.0102 - val_accuracy: 0.9826 - val_loss: 0.0666
# Epoch 97/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9975 - loss: 0.0058 - val_accuracy: 0.6361 - val_loss: 1.9643
# Epoch 98/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9980 - loss: 0.0063 - val_accuracy: 0.9780 - val_loss: 0.0673
# Epoch 99/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9974 - loss: 0.0098 - val_accuracy: 0.8176 - val_loss: 2.2598
# Epoch 100/100
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9970 - loss: 0.0050 - val_accuracy: 0.4840 - val_loss: 26.3763

# %%
optim.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.plot(optim.history['accuracy'])
plt.plot(optim.history['val_accuracy'])
plt.legend(['train', 'validation'], loc='lower right')
plt.title('Accuracy')
plt.show()

# %%
plt.plot(optim.history['loss'])
plt.plot(optim.history['val_loss'])
plt.legend(['train', 'validation'], loc='upper left')
plt.title('Loss')
plt.show()

# %%
np.array(optim.history['val_accuracy']).max()
# Out:
# 0.994500458240509

# %%
from tensorflow.keras.models import load_model

best_model = load_model('checkpoint2.model.keras')

# %%
test_loss, test_acc = best_model.evaluate(X_test, y_test)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727195519.711556    6455 service.cc:146] XLA service 0x793e180091f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727195519.711634    6455 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2024-09-24 10:31:59.729985: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-24 10:31:59.787379: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# E0000 00:00:1727195520.096911    6455 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1727195520.179488    6455 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 10/43 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 5.6459e-04
# I0000 00:00:1727195521.585263    6455 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 41/43 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9995 - loss: 0.0109
# E0000 00:00:1727195522.449560    6445 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1727195522.532480    6445 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9994 - loss: 0.0112

# %%
'Test loss:{0}, Test accuracy: {1}'.format(test_loss,test_acc)
# Out:
# 'Test loss:0.01488907914608717, Test accuracy: 0.9992668628692627'

# %%
# Predict the values from the testing dataset
Y_pred_probs = best_model.predict(X_test)
Y_pred = np.array(Y_pred_probs>=.5)
# compute the confusion matrix
#confusion_mtx = tf.math.confusion_matrix(Y_true, Y_pred)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step

# %%
plt.hist(Y_pred_probs.flatten())
plt.title('Probability distribution of Predictions')
plt.xlabel('Probability')
plt.ylabel('freq')
# Out:
# Text(0, 0.5, 'freq')

# %%
plt.hist(y_test)
plt.title('Probability distribution of True values')
plt.xlabel('Probability')
plt.ylabel('freq')
# Out:
# Text(0, 0.5, 'freq')

# %%
sum(y_test)
# Out:
# 619.0

# %%
Y_pred = Y_pred.astype(float).flatten()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, Y_pred)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
TP=641
TN=38
FP=665
FN=20

# %%
recall = TP/(TP+FN)
precision = TP/(TP+FP)

print(recall,precision)
# Out:
# 0.9697428139183056 0.4908116385911179

# %%
accuracy = (TP+TN)/(TP+TN+FP+FN)
print(accuracy)
# Out:
# 0.49780058651026393
