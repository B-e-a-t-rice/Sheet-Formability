# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from PIL import Image 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import sklearn as sk
from sklearn.model_selection import train_test_split
import pickle

print(tf.__version__)
# Out:
# 2024-11-14 21:39:01.015221: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-14 21:39:01.021617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-14 21:39:01.029290: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-14 21:39:01.031619: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-14 21:39:01.037577: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-14 21:39:01.430111: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.17.0

# %%
gpus = tf.config.list_physical_devices('GPU')
gpuid = 0 #int(args.gpu_id)                                                                                                                           
if gpus:
  # Restrict TensorFlow to only allocate X GB of memory on the first GPU                                                                              
  try:
    tf.config.set_visible_devices(gpus[gpuid], 'GPU')
    tf.config.experimental.set_memory_growth(gpus[gpuid], True)
    '''
    tf.config.set_logical_device_configuration(
        gpus[gpuid],
        [tf.config.LogicalDeviceConfiguration(memory_limit=12000)])
    '''
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized                                                                                   
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731645545.202270    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731645545.225348    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731645545.227601    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731645545.231037    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731645545.233145    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731645545.234734    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731645545.321728    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731645545.322942    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731645545.324084    6290 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-14 21:39:05.325199: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13554 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
with tf.device('/job:localhost/replica:0/task:0/device:CPU:0'):
    inputs = np.load("all_inputs_down_samp.npy")

# %%
inputs.shape
# Out:
# (3470, 512, 512, 1)

# %%
plt.imshow(inputs[0],cmap='grey')
plt.colorbar()

# %%
batchsize = 32

with tf.device('/job:localhost/replica:0/task:0/device:CPU:0'):
    targets = np.load("all_targets_down_samp.npy")
    # train test split
    X_trainval, X_test, y_trainval, y_test = train_test_split(inputs, targets, test_size=0.2)
    X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.2)

with tf.device("/CPU:0") :
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
with tf.device("/GPU:0") :
    train_dataset = train_dataset.shuffle(buffer_size=200).batch(batchsize)
    val_dataset = val_dataset.shuffle(buffer_size=200).batch(batchsize)

# %%
inputs.shape
# Out:
# (3470, 512, 512, 1)

# %%
conv_dim = 16
ff_dim = 32
k_dim = 3
pool_dim = 5
drop_rate = 0.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(conv_dim, kernel_size = (k_dim, k_dim), activation='relu', input_shape=(512, 512, 1)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.ReLU(),
  tf.keras.layers.AveragePooling2D(pool_dim,pool_dim),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Conv2D(conv_dim, kernel_size = (k_dim, k_dim), padding ='valid'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.ReLU(),
  tf.keras.layers.AveragePooling2D(pool_dim,pool_dim),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Conv2D(conv_dim, kernel_size = (k_dim, k_dim), padding ='valid'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.ReLU(),
  tf.keras.layers.AveragePooling2D(pool_dim,pool_dim),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(ff_dim, activation='relu'),
  tf.keras.layers.Dropout(drop_rate),
  tf.keras.layers.Dense(1, activation='sigmoid')  
])

model.summary()
# Out:
# /home/user/anaconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 510, 510, 16)   │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 510, 510, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 510, 510, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 102, 102, 16)   │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 102, 102, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 100, 100, 16)   │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 100, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 100, 100, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 20, 20, 16)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20, 20, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 18, 18, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 18, 18, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 18, 18, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 3, 3, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 3, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 144)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,665 (37.75 KB)
#  Trainable params: 9,569 (37.38 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
#model.compile(optimizer=Adam(learning_rate=1e-4),
#model.compile(optimizer=Adam(learning_rate=1e-2),
#model.compile(optimizer=Adam(learning_rate=1e-5),
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='binary_crossentropy',  
              metrics=['accuracy'])

# %%
model_checkpoint = ModelCheckpoint(
  filepath='checkpoint.model4.keras',
  monitor='val_loss',
  mode='min',
  save_best_only=True)

optim = model.fit(train_dataset,
                  validation_data=val_dataset, 
                  epochs=100, 
                  callbacks=[model_checkpoint])
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731645668.466853    6461 service.cc:146] XLA service 0x7deee0111cf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731645668.466890    6461 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2024-11-14 21:41:08.498798: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-14 21:41:08.629195: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-11-14 21:41:10.742818: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng57{k2=0,k13=2,k14=2,k18=1,k23=0} for conv (f32[16,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[32,16,510,510]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-11-14 21:41:11.136475: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.393826157s
# Trying algorithm eng57{k2=0,k13=2,k14=2,k18=1,k23=0} for conv (f32[16,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[32,16,510,510]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 10/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5975 - loss: 0.6618
# I0000 00:00:1731645672.262948    6461 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.6425 - loss: 0.6211 - val_accuracy: 0.4838 - val_loss: 1.0612
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7859 - loss: 0.4436 - val_accuracy: 0.4838 - val_loss: 2.1962
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8434 - loss: 0.3617 - val_accuracy: 0.4838 - val_loss: 2.2225
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8639 - loss: 0.3108 - val_accuracy: 0.4838 - val_loss: 1.9821
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8565 - loss: 0.3095 - val_accuracy: 0.4838 - val_loss: 3.9921
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8759 - loss: 0.2786 - val_accuracy: 0.4838 - val_loss: 4.9465
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8961 - loss: 0.2562 - val_accuracy: 0.4838 - val_loss: 6.4147
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9083 - loss: 0.2230 - val_accuracy: 0.4820 - val_loss: 3.6853
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9063 - loss: 0.2210 - val_accuracy: 0.6978 - val_loss: 0.7058
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8989 - loss: 0.2321 - val_accuracy: 0.7338 - val_loss: 0.7425
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9117 - loss: 0.2133 - val_accuracy: 0.6115 - val_loss: 1.4973
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9168 - loss: 0.2145 - val_accuracy: 0.5162 - val_loss: 5.1378
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9211 - loss: 0.2131 - val_accuracy: 0.5342 - val_loss: 3.5009
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9285 - loss: 0.1744 - val_accuracy: 0.5162 - val_loss: 3.9926
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9216 - loss: 0.1898 - val_accuracy: 0.5252 - val_loss: 4.1838
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9322 - loss: 0.1666 - val_accuracy: 0.5288 - val_loss: 2.3367
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9347 - loss: 0.1668 - val_accuracy: 0.6924 - val_loss: 0.8453
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9431 - loss: 0.1522 - val_accuracy: 0.8975 - val_loss: 0.2892
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9316 - loss: 0.1577 - val_accuracy: 0.6817 - val_loss: 0.9404
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9464 - loss: 0.1372 - val_accuracy: 0.8309 - val_loss: 0.5240
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9370 - loss: 0.1473 - val_accuracy: 0.5180 - val_loss: 3.3154
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9417 - loss: 0.1463 - val_accuracy: 0.5162 - val_loss: 3.4784
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9367 - loss: 0.1593 - val_accuracy: 0.7644 - val_loss: 0.6228
# Epoch 24/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9312 - loss: 0.1599 - val_accuracy: 0.5971 - val_loss: 1.9375
# Epoch 25/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9437 - loss: 0.1342 - val_accuracy: 0.5198 - val_loss: 3.4488
# Epoch 26/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9539 - loss: 0.1205 - val_accuracy: 0.6295 - val_loss: 1.1652
# Epoch 27/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9433 - loss: 0.1287 - val_accuracy: 0.7662 - val_loss: 0.6899
# Epoch 28/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9527 - loss: 0.1139 - val_accuracy: 0.4928 - val_loss: 3.4611
# Epoch 29/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9543 - loss: 0.1230 - val_accuracy: 0.4856 - val_loss: 4.5633
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9519 - loss: 0.1088 - val_accuracy: 0.7824 - val_loss: 0.6906
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9555 - loss: 0.1076 - val_accuracy: 0.8831 - val_loss: 0.2951
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9669 - loss: 0.0965 - val_accuracy: 0.7626 - val_loss: 0.6786
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9643 - loss: 0.0949 - val_accuracy: 0.7860 - val_loss: 0.6956
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9540 - loss: 0.1076 - val_accuracy: 0.8237 - val_loss: 0.5048
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9579 - loss: 0.1227 - val_accuracy: 0.5198 - val_loss: 3.8380
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9633 - loss: 0.0962 - val_accuracy: 0.5162 - val_loss: 4.5866
# Epoch 37/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9695 - loss: 0.0805 - val_accuracy: 0.5414 - val_loss: 3.3022
# Epoch 38/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9633 - loss: 0.0900 - val_accuracy: 0.6745 - val_loss: 1.3778
# Epoch 39/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9714 - loss: 0.0782 - val_accuracy: 0.5306 - val_loss: 2.6259
# Epoch 40/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9607 - loss: 0.1032 - val_accuracy: 0.6835 - val_loss: 1.5345
# Epoch 41/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9664 - loss: 0.0870 - val_accuracy: 0.5162 - val_loss: 4.9306
# Epoch 42/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9811 - loss: 0.0628 - val_accuracy: 0.5162 - val_loss: 4.7528
# Epoch 43/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9776 - loss: 0.0635 - val_accuracy: 0.5504 - val_loss: 2.6815
# Epoch 44/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9689 - loss: 0.0789 - val_accuracy: 0.6061 - val_loss: 1.0910
# Epoch 45/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9603 - loss: 0.0828 - val_accuracy: 0.6079 - val_loss: 2.1498
# Epoch 46/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9725 - loss: 0.0689 - val_accuracy: 0.5270 - val_loss: 2.3756
# Epoch 47/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9646 - loss: 0.1016 - val_accuracy: 0.5162 - val_loss: 9.3010
# Epoch 48/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9741 - loss: 0.0682 - val_accuracy: 0.5162 - val_loss: 4.5410
# Epoch 49/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9699 - loss: 0.0803 - val_accuracy: 0.8957 - val_loss: 0.2813
# Epoch 50/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9901 - loss: 0.0430 - val_accuracy: 0.9137 - val_loss: 0.2254
# Epoch 51/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9841 - loss: 0.0518 - val_accuracy: 0.5162 - val_loss: 7.1964
# Epoch 52/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9725 - loss: 0.0707 - val_accuracy: 0.7824 - val_loss: 0.9810
# Epoch 53/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9896 - loss: 0.0418 - val_accuracy: 0.8201 - val_loss: 0.6302
# Epoch 54/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9913 - loss: 0.0366 - val_accuracy: 0.6133 - val_loss: 2.4637
# Epoch 55/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9911 - loss: 0.0319 - val_accuracy: 0.8633 - val_loss: 0.5805
# Epoch 56/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9813 - loss: 0.0459 - val_accuracy: 0.5180 - val_loss: 4.9444
# Epoch 57/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9787 - loss: 0.0540 - val_accuracy: 0.8255 - val_loss: 0.6674
# Epoch 58/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9755 - loss: 0.0632 - val_accuracy: 0.5737 - val_loss: 1.6921
# Epoch 59/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9832 - loss: 0.0547 - val_accuracy: 0.8831 - val_loss: 0.4784
# Epoch 60/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9804 - loss: 0.0529 - val_accuracy: 0.5414 - val_loss: 3.2804
# Epoch 61/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9841 - loss: 0.0525 - val_accuracy: 0.8813 - val_loss: 0.2940
# Epoch 62/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9735 - loss: 0.0613 - val_accuracy: 0.7266 - val_loss: 1.4261
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9826 - loss: 0.0379 - val_accuracy: 0.5324 - val_loss: 4.7613
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9865 - loss: 0.0382 - val_accuracy: 0.5162 - val_loss: 8.2412
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9657 - loss: 0.0779 - val_accuracy: 0.5629 - val_loss: 2.3989
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9808 - loss: 0.0552 - val_accuracy: 0.8219 - val_loss: 0.7610
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9846 - loss: 0.0448 - val_accuracy: 0.5270 - val_loss: 4.6911
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9912 - loss: 0.0300 - val_accuracy: 0.5162 - val_loss: 8.6620
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9514 - loss: 0.1241 - val_accuracy: 0.5108 - val_loss: 4.4209
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9924 - loss: 0.0319 - val_accuracy: 0.5162 - val_loss: 6.6133
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9931 - loss: 0.0235 - val_accuracy: 0.6529 - val_loss: 2.0835
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9867 - loss: 0.0455 - val_accuracy: 0.5162 - val_loss: 8.0466
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9869 - loss: 0.0443 - val_accuracy: 0.8273 - val_loss: 0.7500
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9678 - loss: 0.0844 - val_accuracy: 0.5270 - val_loss: 3.1326
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9941 - loss: 0.0239 - val_accuracy: 0.8597 - val_loss: 0.6099
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9960 - loss: 0.0217 - val_accuracy: 0.6079 - val_loss: 2.6921
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9786 - loss: 0.0543 - val_accuracy: 0.7734 - val_loss: 0.9522
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9858 - loss: 0.0467 - val_accuracy: 0.8867 - val_loss: 0.4048
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9966 - loss: 0.0206 - val_accuracy: 0.5324 - val_loss: 4.3596
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9974 - loss: 0.0170 - val_accuracy: 0.5180 - val_loss: 5.9770
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9775 - loss: 0.0569 - val_accuracy: 0.5252 - val_loss: 5.7324
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9734 - loss: 0.0731 - val_accuracy: 0.7284 - val_loss: 1.9468
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9889 - loss: 0.0332 - val_accuracy: 0.6547 - val_loss: 1.9180
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9982 - loss: 0.0129 - val_accuracy: 0.5162 - val_loss: 7.5948
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9919 - loss: 0.0308 - val_accuracy: 0.7932 - val_loss: 1.0940
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9977 - loss: 0.0140 - val_accuracy: 0.5629 - val_loss: 3.8514
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9987 - loss: 0.0130 - val_accuracy: 0.7140 - val_loss: 1.6450
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9908 - loss: 0.0311 - val_accuracy: 0.8435 - val_loss: 0.6299
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9917 - loss: 0.0295 - val_accuracy: 0.6421 - val_loss: 2.7887
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9942 - loss: 0.0241 - val_accuracy: 0.7086 - val_loss: 1.8545
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9972 - loss: 0.0148 - val_accuracy: 0.5594 - val_loss: 3.4429
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9923 - loss: 0.0196 - val_accuracy: 0.5162 - val_loss: 11.7072
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9941 - loss: 0.0228 - val_accuracy: 0.5612 - val_loss: 4.8206
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9880 - loss: 0.0292 - val_accuracy: 0.5126 - val_loss: 7.4573
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9881 - loss: 0.0275 - val_accuracy: 0.5270 - val_loss: 5.1710
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9906 - loss: 0.0250 - val_accuracy: 0.5162 - val_loss: 9.0985
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9908 - loss: 0.0272 - val_accuracy: 0.7734 - val_loss: 0.9246
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9943 - loss: 0.0190 - val_accuracy: 0.5396 - val_loss: 3.8694
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9970 - loss: 0.0168 - val_accuracy: 0.6367 - val_loss: 2.8526
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9857 - loss: 0.0424 - val_accuracy: 0.6475 - val_loss: 2.5774

# %%
optim.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.plot(optim.history['accuracy'])
plt.plot(optim.history['val_accuracy'])
plt.legend(['train', 'validation'], loc='lower right')
plt.title('Accuracy')
plt.show()

# %%
plt.plot(optim.history['loss'])
plt.plot(optim.history['val_loss'])
plt.legend(['train', 'validation'], loc='upper left')
plt.title('Loss')
plt.show()

# %%
np.array(optim.history['val_accuracy']).max()
# Out:
# 0.9136690497398376

# %%
from tensorflow.keras.models import load_model

best_model = load_model('checkpoint.model4.keras')

# %%
test_loss, test_acc = best_model.evaluate(X_test, y_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9321 - loss: 0.1903

# %%
'Test loss:{0}, Test accuracy: {1}'.format(test_loss,test_acc)
# Out:
# 'Test loss:0.18195191025733948, Test accuracy: 0.9365994334220886'

# %%
# Predict the values from the testing dataset
Y_pred_probs = best_model.predict(X_test)
Y_pred = np.array(Y_pred_probs>=.5)
# compute the confusion matrix
#confusion_mtx = tf.math.confusion_matrix(Y_true, Y_pred)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
plt.hist(Y_pred_probs.flatten())
plt.title('Probability distribution of Predictions')
plt.xlabel('Probability')
plt.ylabel('freq')
# Out:
# Text(0, 0.5, 'freq')

# %%
plt.hist(y_test)
plt.title('Probability distribution of True values')
plt.xlabel('Probability')
plt.ylabel('freq')
# Out:
# Text(0, 0.5, 'freq')

# %%
sum(y_test)
# Out:
# 375.0

# %%
Y_pred = Y_pred.astype(float).flatten()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, Y_pred) 
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
TP=152
TN=175
FP=13
FN=1

# %%
recall = TP/(TP+FN)
precision = TP/(TP+FP)

print(recall,precision)
# Out:
# 0.9934640522875817 0.9212121212121213

# %%
(TP+TN)/(TP+TN+FP+FN)
# Out:
# 0.9589442815249267

# %%
sk.metrics.precision_score(y_test, Y_pred)
# Out:
# 0.9389920424403183

# %%
sk.metrics.recall_score(y_test, Y_pred)
# Out:
# 0.944
